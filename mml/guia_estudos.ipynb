# %% [markdown]
# # Plano de Estudos: Mathematics for Machine Learning
#
# Olá! Sou o Professor Syntax.
#
# Este Jupyter Notebook é uma ferramenta interativa para acompanhar seu progresso no livro "Mathematics for Machine Learning". Use-o para marcar capítulos concluídos, adicionar anotações e visualizar seu avanço.
#
# É também uma excelente oportunidade para praticar as habilidades em `pandas` que você desenvolveu. Bons estudos!

# %%
# Célula 1: Setup e Imports
# Rode esta célula para importar as bibliotecas necessárias.

import pandas as pd
from datetime import date, timedelta

# %%
# Célula 2: Criação do DataFrame do Plano de Estudos
# Contém a estrutura de dados completa do livro.

study_plan_data = [
    # Prefácio
    {'Part': 'Preamble', 'Chapter': 0, 'Section': 0.0, 'Title': 'Foreword', 'Status': 'Não iniciado', 'Priority': 'Baixa', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},

    # Parte I: Mathematical Foundations
    {'Part': 'Part I', 'Chapter': 1, 'Section': 1.0, 'Title': 'Introduction and Motivation', 'Status': 'Não iniciado', 'Priority': 'Média', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part I', 'Chapter': 2, 'Section': 2.0, 'Title': 'Linear Algebra', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': 'Fundamental Chapter'},
    {'Part': 'Part I', 'Chapter': 3, 'Section': 3.0, 'Title': 'Analytic Geometry', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part I', 'Chapter': 4, 'Section': 4.0, 'Title': 'Matrix Decompositions', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part I', 'Chapter': 5, 'Section': 5.0, 'Title': 'Vector Calculus', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part I', 'Chapter': 6, 'Section': 6.0, 'Title': 'Probability and Distributions', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part I', 'Chapter': 7, 'Section': 7.0, 'Title': 'Continuous Optimization', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},

    # Parte II: Central Machine Learning Problems
    {'Part': 'Part II', 'Chapter': 8, 'Section': 8.0, 'Title': 'When Models Meet Data', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part II', 'Chapter': 9, 'Section': 9.0, 'Title': 'Linear Regression', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part II', 'Chapter': 10, 'Section': 10.0, 'Title': 'Dimensionality Reduction with Principal Component Analysis', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part II', 'Chapter': 11, 'Section': 11.0, 'Title': 'Density Estimation with Gaussian Mixture Models', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''},
    {'Part': 'Part II', 'Chapter': 12, 'Section': 12.0, 'Title': 'Classification with Support Vector Machines', 'Status': 'Não iniciado', 'Priority': 'Alta', 'StudyDate': None, 'ReviewDate': None, 'Confidence': 0, 'Notes': ''}
]

df = pd.DataFrame(study_plan_data)

print("Plano de Estudos criado com sucesso!")
df.head()
# Out:
# Plano de Estudos criado com sucesso!
#        Part  Chapter  Section                        Title        Status  \
# 0  Preamble        0      0.0                     Foreword  Não iniciado
# 1    Part I        1      1.0  Introduction and Motivation  Não iniciado
# 2    Part I        2      2.0               Linear Algebra  Não iniciado
# 3    Part I        3      3.0            Analytic Geometry  Não iniciado
# 4    Part I        4      4.0        Matrix Decompositions  Não iniciado
#
#   Priority StudyDate ReviewDate  Confidence                Notes
# 0    Baixa      None       None           0
# 1    Média      None       None           0
# 2     Alta      None       None           0  Fundamental Chapter
# 3     Alta      None       None           0
# 4     Alta      None       None           0

# %%
# Célula 3: Função Auxiliar para Atualizar Progresso

def completar_capitulo(df, chapter_number, confidence_level=90):
    """
    Marca um capítulo inteiro e suas seções como 'Concluído' e define a data de estudo.
    """
    today = date.today()
    review_date = today + timedelta(days=30) # Agenda uma revisão para daqui a 30 dias
    
    # Seleciona todas as entradas do capítulo
    chapter_mask = df['Chapter'] == chapter_number
    
    # Atualiza as colunas
    df.loc[chapter_mask, 'Status'] = 'Concluído'
    df.loc[chapter_mask, 'StudyDate'] = today.strftime('%Y-%m-%d')
    df.loc[chapter_mask, 'ReviewDate'] = review_date.strftime('%Y-%m-%d')
    df.loc[chapter_mask, 'Confidence'] = confidence_level
    
    print(f"Capítulo {chapter_number} marcado como 'Concluído'!")
    return df

# %% [markdown]
# ## 🚀 Como Usar Este Roteiro
#
# 1.  **Rode as células 1, 2 e 3** para carregar o plano de estudos e a função auxiliar.
# 2.  **Atualize seu progresso** na Célula 4, usando a função `completar_capitulo()` para os capítulos que você já finalizou.
# 3.  **Adicione anotações** na Célula 5 para seções específicas que você queira revisar.
# 4.  **Visualize seu avanço** rodando a Célula 6 para gerar um gráfico do seu status.
# 5.  **Salve seu progresso** na Célula 7 para não perder suas atualizações.

# %%
# Célula 4: ATUALIZE SEU PROGRESSO AQUI

print("Marcando capítulos já concluídos...")
df = completar_capitulo(df, 2, confidence_level=70)
df = completar_capitulo(df, 3, confidence_level=60)
df = completar_capitulo(df, 4, confidence_level=50)
print("\n--- Progresso Atualizado! ---")

# Exibe o DataFrame com as linhas atualizadas
df[df['Status'] == 'Concluído']
# Out:
# Marcando capítulos já concluídos...
# Capítulo 2 marcado como 'Concluído'!
# Capítulo 3 marcado como 'Concluído'!
# Capítulo 4 marcado como 'Concluído'!
#
# --- Progresso Atualizado! ---
#      Part  Chapter  Section                  Title     Status Priority  \
# 2  Part I        2      2.0         Linear Algebra  Concluído     Alta
# 3  Part I        3      3.0      Analytic Geometry  Concluído     Alta
# 4  Part I        4      4.0  Matrix Decompositions  Concluído     Alta
#
#     StudyDate  ReviewDate  Confidence                Notes
# 2  2025-09-28  2025-10-28          70  Fundamental Chapter
# 3  2025-09-28  2025-10-28          60
# 4  2025-09-28  2025-10-28          50

# %% [markdown]
# ## ✍️ Adicionando Anotações
#
# Você pode adicionar notas específicas para qualquer seção usando `.loc` para encontrar a linha e atualizar a coluna 'Notes'. Isso é ótimo para lembrar de conceitos importantes ou pontos que precisam de revisão.

# %%
# Célula 5: Adicione suas anotações pessoais

# Exemplo: Adicionando uma nota sobre SVD no capítulo 4
df.loc[(df['Chapter'] == 4) & (df['Title'] == 'Matrix Decompositions'), 'Notes'] = 'Conceito chave para PCA! Revisar a conexão com autovetores.'

# Mostrando a nota que acabamos de adicionar
df[df['Notes'] != '']
# Out:
#      Part  Chapter  Section                  Title     Status Priority  \
# 2  Part I        2      2.0         Linear Algebra  Concluído     Alta
# 4  Part I        4      4.0  Matrix Decompositions  Concluído     Alta
#
#     StudyDate  ReviewDate  Confidence  \
# 2  2025-09-28  2025-10-28          70
# 4  2025-09-28  2025-10-28          50
#
#                                                Notes
# 2                                Fundamental Chapter
# 4  Conceito chave para PCA! Revisar a conexão com...

# %% [markdown]
# ## 📊 Visualizando seu Progresso
#
# Uma imagem vale mais que mil palavras! Use o código abaixo para criar um gráfico de barras simples e ver rapidamente quantas seções você já concluiu versus quantas ainda faltam.

# %%
# Célula 6: Gerar Gráfico de Progresso

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='Status', palette=['#ff9999','#66b3ff'], order=['Não iniciado', 'Concluído'])
ax.set_title('Progresso Geral dos Estudos', fontsize=16)
ax.set_xlabel('Status', fontsize=12)
ax.set_ylabel('Número de Capítulos/Seções', fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_32155/985417651.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Status', palette=['#ff9999','#66b3ff'], order=['Não iniciado', 'Concluído'])

# %% [markdown]
# ## 💾 Salvando e Carregando seu Progresso
#
# Para não perder suas atualizações, salve o DataFrame em um arquivo CSV. Na próxima vez que abrir o notebook, você pode carregá-lo a partir deste arquivo, pulando os passos de criação e atualização.

# %%
# Célula 7: Salve ou Carregue seu progresso

file_path = 'meu_plano_de_estudos_mml.csv'

# --- SALVAR PROGRESSO ---
df.to_csv(file_path, index=False)
print(f"Plano de estudos salvo em '{file_path}'!")

# --- PARA CARREGAR DA PRÓXIMA VEZ ---
# Na próxima vez que usar o notebook, você pode pular as células 2, 4 e 5 
# e simplesmente rodar esta parte para carregar seu progresso salvo.

# Descomente a linha abaixo para carregar seu progresso
# df = pd.read_csv(file_path)
# print("Plano de estudos carregado com sucesso!")

# %% [markdown]
# ---
# Este notebook agora é sua ferramenta. Use-a, modifique-a e, o mais importante, continue aprendendo.
#
# Bons estudos!
#
# *- Professor Syntax*
